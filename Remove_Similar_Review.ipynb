# %% [markdown]
# <a href="https://colab.research.google.com/github/khushbuchuahan3/word2vec/blob/main/Remove_Similar_Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 57.3 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 52.2 MB/s
# ...
#      |████████████████████████████████| 120 kB 72.1 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 64.6 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=ac47ca5c16359b0a11106b1789b78c7884f7c20931f5ba3afc2deb3ca0e33eb8
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import re
import nltk
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download("stopwords")

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity,euclidean_distances
import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# ...

# %%
le=WordNetLemmatizer()

# %%
data=pd.read_csv('/content/drive/MyDrive/review_text.csv',names=["label"])
data
# Out:
#                                                 label
# 0        This is the first pair of shoes I got online
# 1   First few days was a tad tight but now that th...
# 2   The soles are not hard but not too flexible ei...
# 3   Usually wear a 9.5 but after trying them on at...
# 4                   I had the Kinvara 4 running shoes
# ..                                                ...
# 95                        These are very nice shoes .
# 96                                   Quality is great
# 97                            I like the shoe a lot .
# 98  I bought the yellow colored from Amazon ( as m...
# 99  Once I wore the shoes for a few days the shipp...
#
# [100 rows x 1 columns]

# %%
cleaned_corpus=[]
for i in range(0,len(data)):
  review=re.sub("[^A-Za-z0-9]"," ",data['label'][i])
  review=review.lower()
  review=review.split()
  review=[le.lemmatize(word) for word in review if word  not in stopwords.words("english")]
  review=" ".join(review)
  cleaned_corpus.append(review)

# %%
cleaned_corpus=list(cleaned_corpus)
cleaned_corpus
# Out:
# ['first pair shoe got online',
#  'first day tad tight broken fit like glove',
#  'sol hard flexible either',
#  'usually wear 9 5 trying store first went 10',
#  'kinvara 4 running shoe',
#  'width wise seem average maybe slightly narrow much',
#  'use one go gym use 9 run',
#  'n come second set lace',
#  'went half size bigger normal',
#  'let see perform',
#  'item received per described',
#  'firstthe lace made stretchy',
#  '100 shoe expect get perfect finishing',
#  'walk 3 mile per day indoors carpet job',
#  'wear day everyday always foot',
#  'climbed angel landing shoe',
#  'originally bought use travel shoe',
#  'color darker last pair',
#  'worn training competing full ironman marathon',
#  'foot least 8 hour day',
#  'husband us thesefor sped walking road',
#  'purchase brand',
#  'height midsole expected',
#  'comfortable fit good look',
#  'problem since switching different sock though',
#  'good shoe running practice',
# ...

# %%
cv=CountVectorizer(max_features=200)
x=cv.fit_transform(cleaned_corpus).todense()
print(cv.vocabulary_)
# Out:
# {'first': 53, 'pair': 117, 'shoe': 140, 'online': 115, 'day': 43, 'tad': 164, 'tight': 168, 'broken': 21, 'fit': 55, 'like': 92, 'glove': 63, 'sol': 150, 'hard': 68, 'flexible': 57, 'usually': 177, 'wear': 180, 'trying': 173, 'store': 156, 'went': 185, '10': 0, 'kinvara': 84, 'running': 131, 'width': 187, 'wise': 189, 'seem': 135, 'average': 12, 'maybe': 104, 'slightly': 143, 'much': 108, 'use': 175, 'one': 114, 'go': 64, 'gym': 67, 'run': 130, 'come': 32, 'second': 133, 'set': 138, 'lace': 85, 'size': 142, 'bigger': 17, 'let': 89, 'see': 134, 'item': 82, 'received': 127, 'per': 118, 'firstthe': 54, 'made': 101, 'stretchy': 158, '100': 1, 'get': 62, 'perfect': 119, 'finishing': 52, 'walk': 178, 'mile': 107, 'indoors': 78, 'carpet': 24, 'job': 83, 'everyday': 46, 'always': 7, 'foot': 59, 'climbed': 29, 'angel': 9, 'bought': 18, 'travel': 172, 'color': 30, 'darker': 42, 'last': 86, 'worn': 196, 'training': 171, 'competing': 37, 'full': 61, 'ironman': 80, 'marathon': 103, 'least': 88, '
# ...

# %%
distances=[]
for i in range(0,len(x)-1):
     distance=euclidean_distances(x[i],x[i+1])
     distances.append(distance)

# %%
distances
# Out:
# [array([[3.16227766]]),
#  array([[3.31662479]]),
#  array([[3.16227766]]),
#  array([[3.16227766]]),
#  array([[3.16227766]]),
#  array([[3.87298335]]),
#  array([[3.46410162]]),
#  array([[2.64575131]]),
#  array([[2.23606798]]),
#  array([[2.23606798]]),
#  array([[2.64575131]]),
#  array([[3.]]),
#  array([[3.46410162]]),
#  array([[3.16227766]]),
#  array([[2.82842712]]),
#  array([[2.23606798]]),
#  array([[2.82842712]]),
#  array([[3.16227766]]),
#  array([[3.16227766]]),
#  array([[3.16227766]]),
#  array([[2.82842712]]),
#  array([[2.23606798]]),
#  array([[2.64575131]]),
#  array([[3.16227766]]),
#  array([[3.16227766]]),
#  array([[3.60555128]]),
#  array([[4.58257569]]),
#  array([[4.12310563]]),
#  array([[3.16227766]]),
#  array([[3.87298335]]),
#  array([[2.82842712]]),
#  array([[2.]]),
#  array([[2.23606798]]),
#  array([[2.23606798]]),
#  array([[1.73205081]]),
#  array([[2.64575131]]),
#  array([[2.64575131]]),
#  array([[2.23606798]]),
#  array([[2.64575131]]),
# ...
